# %% [markdown]
# # Perceptual learning in children with autism spectrum disorder (ASD) aka the fishing experiment
# **Researchers: Lisa Lemmens, Sander Van de Cruys, Laurie-Anne Sapey-Triomphe, Ilse Noens, Johan Wagemans**
# ___
#
#
# See task,  procedure and participant description in the [Manuscript draft](https://docs.google.com/document/d/1c6YqDHVXnDOWc-UlmezoIzxbPWXUFcKpZEnhcbZ8Nnc/edit?usp=sharing)
#
#
# Notes:
#
# * Warning: This is a working document, and may contain coding or reasoning errors...
#
#
#
# <img src="img/task.png" style="height:800px">

# %% [markdown]
# Importing required python libraries:

# %%
import glob, os #file utilities
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt # roughly ~base R plotting functionality
import pandas as pd #roughly ~base R & tidyr functionality 
import seaborn as sns #roughly ~ggplot2 functionality
import statsmodels.api as sm
from statsmodels import stats
import statsmodels.formula.api as smf
from bambi import Model
import pymc3 as pm
import bambi
import warnings
import ptitprince as pt # python version of rain cloud plots
import pingouin as pg # statistical tests
import rpy2
from sklearn import preprocessing #for scale function
warnings.filterwarnings('ignore')

#to make the plots appear inline, and saved in notebook:
# %matplotlib inline
sns.set_context("paper") # seaborn function to make plots according to purpose (talk, paper, poster, notebook)

# We'll show people what versions we use
import datetime
now  = datetime.datetime.now().isoformat()
print('Ran on ' + now)
import IPython
print(IPython.sys_info())
#!pip freeze | grep -E 'seaborn|matplotlib|pandas|statsmodels|pingouin'

# %load_ext watermark
# %watermark -v -m -p scipy,numpy,rpy2,sklearn,seaborn,statsmodels,pandas,matplotlib,pingouin -g
# Out:
# Ran on 2019-10-15T15:22:11.759054
# {'commit_hash': '741169a00',
#  'commit_source': 'installation',
#  'default_encoding': 'UTF-8',
#  'ipython_path': '/usr/local/lib/python3.7/dist-packages/IPython',
#  'ipython_version': '7.7.0',
#  'os_name': 'posix',
#  'platform': 'Linux-5.0.0-31-generic-x86_64-with-Ubuntu-19.04-disco',
#  'sys_executable': '/usr/bin/python',
#  'sys_platform': 'linux',
#  'sys_version': '3.7.3 (default, Oct  7 2019, 12:56:13) \n[GCC 8.3.0]'}
# CPython 3.7.3
# IPython 7.7.0
#
# scipy 1.3.0
# numpy 1.17.0
# rpy2 3.0.5
# sklearn 0.21.3
# seaborn 0.9.0
# statsmodels 0.10.1
# pandas 0.25.0
# matplotlib 3.1.1
# pingouin 0.2.8
#
# compiler   : GCC 8.3.0
# system     : Linux
# release    : 5.0.0-31-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit
# Git hash   : 9ee2540db2b34d1861bf66212bf4c42725633382

# %% [markdown]
# # Importing data

# %%
# importing data
df = pd.DataFrame()    
all_files = glob.glob(os.path.join('data',"exp_*.csv")) # get list of individual data files
all_files.sort()

import re 

for file in all_files:
    idcode = re.findall('\d+', file)[0]
    if idcode in ['002','304','315','316','321','322']: continue
    dfnew = pd.read_csv(file).assign(subjectId=int(idcode)) #read file and add column for id
    df = pd.concat([df, dfnew], ignore_index=True)

df['group'] = np.where(df['subjectId']<100, 'ASD', 'TD')

#remove practice trials
df = df[(df.block_index > -1)]
#df["id"] = df["id"].astype('category')
df["trial_sigma"] = df["trial_sigma"].astype('category')
df['final'] = np.where(df['final_ori']>180, df['final_ori'] - 360, df['final_ori'])  #variable final, goes from -180 to +180, in line with presented orientations ( -28° to 118°) instead of final_ori that goes from 0 to 360 degrees 
df.subjectId= df.subjectId.astype(str)

df.head()
# Out:
#     trial_index  block_index  block_trial  block_mu  block_sigma  \
# 8             8            0            0        22           20
# 9             9            0            1        22           20
# 10           10            0            2        22           20
# 11           11            0            3        22           20
# 12           12            0            4        22           20
#
#     trial_mu_deviation  trial_mu trial_sigma  trial_mean  initial_ori  \
# 8                  -10        32          40    0.613132            0
# 9                  -40        62          40    1.059317           26
# 10                 -20        42          10    0.731784          146
# 11                 -20        42          10    0.716934           39
# 12                  10        12          40    0.316734           47
#
#     final_ori        rt subjectId group  final
# 8       342.6  3.916931         1   ASD  -17.4
# 9        54.1  2.883790         1   ASD   54.1
# ...

# %%
df.head(50).groupby('trial_sigma').count()
# Out:
#              trial_index  block_index  block_trial  block_mu  block_sigma  \
# trial_sigma
# 10                    25           25           25        25           25
# 40                    25           25           25        25           25
#
#              trial_mu_deviation  trial_mu  trial_mean  initial_ori  final_ori  \
# trial_sigma
# 10                           25        25          25           25         25
# 40                           25        25          25           25         25
#
#              ...  prior  distance_prior_response  distance_prior  bias  slope  \
# trial_sigma  ...
# 10           ...     25                       25              25    25     25
# 40           ...     25                       25              25    25     25
#
#              arc_slope  rt_norm  distance_prior_response_conv  \
# trial_sigma
# 10                  25       25                            25
# 40                  25       25                            25
#
# ...

# %%
print('Variables:\n', df.columns)
print('variables:\n', df.dtypes)
print('nb of participants:', len(df['subjectId'].unique()))
print('trials per participant:', len(df)/ len(df['subjectId'].unique()))
df.groupby('group')['subjectId'].nunique()
# Out:
# Variables:
#  Index(['trial_index', 'block_index', 'block_trial', 'block_mu', 'block_sigma',
#        'trial_mu_deviation', 'trial_mu', 'trial_sigma', 'trial_mean',
#        'initial_ori', 'final_ori', 'rt', 'subjectId', 'group', 'final'],
#       dtype='object')
# variables:
#  trial_index              int64
# block_index              int64
# block_trial              int64
# block_mu                 int64
# block_sigma              int64
# trial_mu_deviation       int64
# trial_mu                 int64
# trial_sigma           category
# trial_mean             float64
# initial_ori              int64
# final_ori              float64
# rt                     float64
# subjectId               object
# group                   object
# final                  float64
# dtype: object
# nb of participants: 49
# trials per participant: 400.0
# group
# ASD    24
# TD     25
# Name: subjectId, dtype: int64

# %% [markdown]
# ### Explanation of the data variables
#
# - trial_index = number of trials
# - block_index = number of blocks (8 blocks in total, block -1 is practice block)
# - block_trial = number of trials within blocks
# - block_mu = mean orientation of the prior within a block (same first 6 blocks)
# - block_sigma = standard deviation of prior within a block (always 20°)
# - trial_mu_deviation = deviation mean orientation from mean of prior
# - trial_mu = mean orientation of distribution from which the directions of moving dots are sampled per trial
# - trial_sigma = variability of moving dots per trial (10 or 40°)
# - trial_mean = actual mean orientation of moving dots per trial
# - initial_ori = initial orientation of the fishing rod
# - final_ori = response
# - rt

# %% [markdown]
# ## Adding informative (computed) variables

# %%
#create factor variables for means of priors

# prior_mean is factor variable for mean of prior
df['prior_mean'] = np.where(df['block_mu'] == 22, 22, 68)

# Session variable indicates whether the first prior was the one with 22 mean or 68 mean.
df['session'] = np.where(((df.block_mu == 22) & (df.block_index.isin([0,1,2,3,4,5]))) | ((df.block_mu == 68) & (df.block_index.isin([6,7]))) , "22_first", "68_first")

#Create factor variable for blocks of 100 trials
def blocks(series):
    if series < 2:
        return 1
    elif 1 < series < 4:
        return 2
    elif 3 < series < 6:
        return 3
    elif series > 5:
        return 4

df['tr_100'] = df['block_index'].apply(blocks)

#Create factor variable to indicate whether it is the first or the second prior
df['prior'] = np.where((df.block_index < 6), "prior 1", "prior 2") #prior 1 or prior 2


#distance_prior_response is the final chosen direction minus mean of the prior in that block; 
df['distance_prior_response'] = df.final - df.block_mu
df['distance_trial'] = df.final - df.trial_mu
#distance_prior is the presented motion direction minus the mean of the prior in that block. 
df['distance_prior'] = df.trial_mu - df.block_mu 
df['distance_prior_response'] = np.where((df.distance_prior_response > 180), df.distance_prior_response - 360, df.distance_prior_response)
df['distance_prior_response'] = np.where((df.distance_prior_response < -180), df.distance_prior_response + 360, df.distance_prior_response)
df['bias']= df.distance_prior_response - df.distance_prior
df['bias'] = np.where((df.bias < -180), df.bias + 360, df.bias)
df['bias'] = np.where((df.bias > 180), df.bias - 360, df.bias)
#slope like in Vilares (see supplementary):
df['slope']=df.distance_prior_response/(df.trial_mu - df.block_mu)
#Instantaneous slope like in Vilares (see supplementary):
df['arc_slope'] = (np.arctan(-0.5 + df.slope)/np.pi)+0.5
#rt normalised by distance between chosen orientation and initial orientation of the presented fishing rod
df['rt_norm']=df.rt/(abs(df.final_ori-df.initial_ori))
df['rt_norm']= df.rt_norm.replace([np.inf, -np.inf], np.nan)

#Convert the responses of sessions with 22 degree prior first into 68 degrees first by inverting the sign.
df['distance_prior_response_conv'] = np.where(df.session =="22_first", df.distance_prior_response*(-1), df.distance_prior_response)
#same for the distance of the presented directions from the priors in the 22° first sessions.
df['distance_prior_conv'] = np.where(df.session =="22_first", df.distance_prior*(-1), df.distance_prior)
#same for bias.
df['bias_conv'] = np.where(df.session =="22_first", df.bias*(-1), df.bias)

df['trial_mean_deg'] = np.degrees(df.trial_mean)

# %% [markdown]
# # Add descriptive data

# %%
# add demographics
demo_asd = pd.read_csv("data/deelnemers_ASD.csv")
demo_td = pd.read_csv("data/CONTROLEdeelnemers.csv")

dfdescr = pd.concat([demo_asd, demo_td], ignore_index=True)

vars= ["SubjectId","leeftijd", "Geslacht", "VIQ", "PIQ","SRS_TOTAAL","SRS_SB", "SRS_SCOG", "SRS_SCOM", "SRS_SM", "SRS_AP", "IU","CBCL","SP", "ADOS"]

dfdescr = dfdescr[vars]


dfdescr['TIQ'] = (dfdescr.PIQ + dfdescr.VIQ)/2

dfdescr = dfdescr[dfdescr.SubjectId.notna()]

dfdescr.SubjectId= dfdescr.SubjectId.astype(int)


for i in dfdescr.columns:
    if i=='SubjectId':
        continue
    dfdescr[i] = pd.to_numeric(dfdescr[i], errors='coerce')

dfdescr.SubjectId= dfdescr.SubjectId.astype(str)

# %%
dfdescr.head()
# Out:
#   SubjectId  leeftijd  Geslacht    VIQ    PIQ  SRS_TOTAAL  SRS_SB  SRS_SCOG  \
# 0         1     10.22       0.0   92.0   97.0        91.0    67.0      89.0
# 1         2     13.66       0.0   62.0   91.0        95.0    67.0     102.0
# 2         3     11.40       0.0  122.0  103.0        86.0    63.0      82.0
# 3         4     10.72       0.0  127.0  120.0        77.0    73.0      71.0
# 4         5     11.93       0.0  114.0  132.0        96.0    83.0      94.0
#
#    SRS_SCOM  SRS_SM  SRS_AP    IU  CBCL     SP  ADOS    TIQ
# 0      91.0    73.0    89.0  39.0  60.0    NaN   5.0   94.5
# 1      87.0    78.0    95.0  41.0  70.0  142.0   3.0   76.5
# 2      87.0    67.0    89.0   NaN   NaN  162.0   NaN  112.5
# 3      65.0    65.0    92.0  47.0  66.0    NaN   9.0  123.5
# 4      85.0    83.0    92.0  53.0  57.0  180.0   5.0  123.0

# %%
df= pd.merge(df, dfdescr, how='left', left_on='subjectId', right_on='SubjectId')
#add variable split SRS
df['SRSsplit'] = pd.qcut(df.SRS_TOTAAL, 3, labels=['low','mid','high'])
df.head()
# Out:
#    trial_index  block_index  block_trial  block_mu  block_sigma  \
# 0            8            0            0        22           20
# 1            9            0            1        22           20
# 2           10            0            2        22           20
# 3           11            0            3        22           20
# 4           12            0            4        22           20
#
#    trial_mu_deviation  trial_mu trial_sigma  trial_mean  initial_ori  ...  \
# 0                 -10        32          40    0.613132            0  ...
# 1                 -40        62          40    1.059317           26  ...
# 2                 -20        42          10    0.731784          146  ...
# 3                 -20        42          10    0.716934           39  ...
# 4                  10        12          40    0.316734           47  ...
#
#    SRS_SCOG  SRS_SCOM SRS_SM SRS_AP    IU  CBCL  SP  ADOS   TIQ  SRSsplit
# ...

# %% [markdown]
# # Do matching on IQ, gender and age
#
# ### Age

# %%
dfm = df.groupby(['group', 'subjectId']).leeftijd.mean().reset_index()

sns.distplot(dfm[dfm.group=='ASD'].leeftijd.dropna(), label="ASD", bins=6)
sns.distplot(dfm[dfm.group=='TD'].leeftijd.dropna(), label="TD", bins=6)
plt.legend();

dfm.groupby(['group']).describe()
# Out:
#       leeftijd
#          count       mean       std    min    25%    50%        75%        max
# group
# ASD       23.0  12.049809  1.329276  10.22  10.91  11.84  13.165822  14.986301
# TD        25.0  11.873479  1.476749  10.01  10.90  11.52  12.643836  14.947945

# %%
pg.ttest(dfm[dfm.group=="ASD"].leeftijd, dfm[dfm.group=="TD"].leeftijd, paired=False, tail='one-sided').round(2)
# Out:
#            T    dof     tail  p-val        CI95%  cohen-d   BF10  power
# T-test  0.44  45.98  greater   0.33  [-0.5, inf]     0.12  0.622   0.11

# %% [markdown]
# ### IQ

# %%
dfm = df.groupby(['group', 'subjectId']).TIQ.mean().reset_index()

sns.distplot(dfm[dfm.group=='ASD'].TIQ.dropna(), label="ASD", bins=6)
sns.distplot(dfm[dfm.group=='TD'].TIQ.dropna(), label="TD", bins=6)
plt.legend();

dfm.groupby(['group']).describe()
# Out:
#         TIQ
#       count        mean        std   min    25%    50%    75%    max
# group
# ASD    23.0  105.043478  13.275844  82.5   96.5  102.5  115.5  123.5
# TD     25.0  107.000000   8.509798  84.5  103.0  108.0  110.0  131.0

# %%
pg.ttest(dfm[dfm.group=="ASD"].TIQ, dfm[dfm.group=="TD"].TIQ, paired=False, tail='one-sided').round(2)
# Out:
#           T    dof  tail  p-val         CI95%  cohen-d   BF10  power
# T-test -0.6  36.94  less   0.28  [-inf, 3.53]     0.18  0.667   0.15

# %%
dfm = df.groupby(['group', 'subjectId']).VIQ.mean().reset_index()
pg.ttest(dfm[dfm.group=="ASD"].VIQ, dfm[dfm.group=="TD"].VIQ, paired=False, tail='one-sided').round(2)
# Out:
#            T    dof  tail  p-val         CI95%  cohen-d   BF10  power
# T-test -0.68  30.67  less   0.25  [-inf, 4.02]      0.2  0.693   0.17

# %%
dfm = df.groupby(['group', 'subjectId']).PIQ.mean().reset_index()
pg.ttest(dfm[dfm.group=="ASD"].PIQ, dfm[dfm.group=="TD"].PIQ, paired=False, tail='one-sided').round(2)
# Out:
#            T    dof  tail  p-val         CI95%  cohen-d   BF10  power
# T-test -0.27  42.22  less   0.39  [-inf, 6.51]     0.08  0.593   0.08

# %% [markdown]
# ### CBCL

# %%
dfm = df.groupby(['group', 'subjectId']).CBCL.mean().reset_index()
sns.distplot(dfm[dfm.group=='ASD'].CBCL.dropna(), label="ASD", bins=6)
sns.distplot(dfm[dfm.group=='TD'].CBCL.dropna(), label="TD", bins=6)
plt.legend();

dfm.groupby(['group']).describe()
# Out:
#        CBCL
#       count       mean       std   min   25%   50%   75%   max
# group
# ASD    19.0  57.578947  7.618076  50.0  51.0  56.0  61.0  77.0
# TD     21.0  54.000000  5.291503  50.0  50.0  51.0  56.0  66.0

# %%
pg.ttest(dfm[dfm.group=="ASD"].CBCL, dfm[dfm.group=="TD"].CBCL, paired=False, tail='one-sided').round(2)
# Out:
#            T    dof     tail  p-val        CI95%  cohen-d   BF10  power
# T-test  1.71  31.71  greater   0.05  [0.03, inf]     0.55  1.932   0.52

# %% [markdown]
# ### Gender

# %%
dfm = df.groupby(['group', 'subjectId']).Geslacht.mean().reset_index()
dfc = dfm.groupby(['group']).Geslacht.sum().reset_index()
dfc
# Out:
#   group  Geslacht
# 0   ASD       8.0
# 1    TD      12.0

# %%
count = dfc.Geslacht.values.tolist()
nobs= dfm.groupby(['group']).Geslacht.count().reset_index().Geslacht.values.tolist()
stats.proportion.proportions_chisquare(count,nobs, value=None)[:2]
# Out:
# (0.8610186335403733, 0.35345379117853537)

# %% [markdown]
# # Explore questionnaire data

# %%
dfsumQ= df.groupby(['subjectId', 'group']).agg({'SRS_TOTAAL':'mean', 'SP': 'mean', 'IU': 'mean', 'TIQ':'mean'}).reset_index()

sns.lmplot(x="TIQ", y="SRS_TOTAAL", hue="group", data=dfsumQ);

for i in ['SRS_TOTAAL', 'IU', 'SP']:
    plt.figure()
    g = sns.distplot(dfsumQ[dfsumQ.group=='ASD'][i].dropna(), label="ASD", bins=6)
    sns.distplot(dfsumQ[dfsumQ.group=='TD'][i].dropna(), label="TD", bins=6)
    plt.legend()

# %% [markdown]
# "The SRS has high internal consistency (Cronbach’s alpha = 0.76), and has good discriminant validity (Constantino 2002). Sensitivity and specificity are 0.85 and 0.75, respectively, when the SRS total score of 75 is used as the cutoff (Bölte et al. 2011; Constantino 2002)." (Moody et al 2017)
#
# This percentage of our ASD group scores below 75:

# %%
from scipy import stats
stats.percentileofscore(dfsumQ[dfsumQ.group=='ASD'].SRS_TOTAAL.dropna(), 75)
# Out:
# 15.0

# %%
# values of low,mid,high cut-offs of srs
dfsumQ.SRS_TOTAAL.quantile([.33,.67])
# Out:
# 0.33    51.74
# 0.67    80.65
# Name: SRS_TOTAAL, dtype: float64

# %% [markdown]
# **Missing questionnaire data:**

# %%
dfsumQ.SP.isna().sum(), dfsumQ.SRS_TOTAAL.isna().sum(), dfsumQ.IU.isna().sum()
# Out:
# (23, 9, 9)

# %% [markdown]
# ## Do questionnaire scores differ between groups?

# %%
pg.ttest(dfsumQ.query('group=="ASD"').SRS_TOTAAL, dfsumQ.query('group=="TD"').SRS_TOTAAL, paired=False, tail='one-sided').round(2)
# Out:
#            T  dof     tail  p-val        CI95%  cohen-d       BF10  power
# T-test  9.85   38  greater    0.0  [34.6, inf]     3.11  1.987e+09    1.0

# %%
pg.ttest(dfsumQ.query('group=="ASD"').SP, dfsumQ.query('group=="TD"').SP, paired=False, tail='one-sided').round(2)
# Out:
#            T  dof     tail  p-val         CI95%  cohen-d    BF10  power
# T-test  3.43   24  greater    0.0  [16.47, inf]     1.35  32.942   0.95

# %%
pg.ttest(dfsumQ.query('group=="ASD"').IU, dfsumQ.query('group=="TD"').IU, paired=False, tail='one-sided').round(2)
# Out:
#            T    dof     tail  p-val         CI95%  cohen-d       BF10  power
# T-test  8.03  19.74  greater    0.0  [18.86, inf]     2.78  1.384e+07    1.0

# %% [markdown]
# Yes, for all three, consistent with diagnosis. IU is higher in ASD as well, consistent with earlier reports (Boulter et al. 2014).

# %%
df.to_csv('allDataInclDescr.csv')

# %% [markdown]
# # Check distributions of main task variables

# %%
sns.distplot(df.distance_prior_response, kde=False);

# %%
sns.distplot(df.bias_conv, kde=False);

# %%
sns.distplot(df.trial_mu, kde=False);

# %%
sns.distplot(df.final, kde=False);

# %% [markdown]
# # TAPAS fitting

# %%
import transplant
ml = transplant.Matlab()
ml.cd("/home/sander/local/MATLAB/tapas/HGF/")
ml.pwd()
# Out:
# ...
#
#                             < M A T L A B (R) >
#                   Copyright 1984-2018 The MathWorks, Inc.
#                    R2018a (9.4.0.813654) 64-bit (glnxa64)
#                              February 23, 2018
#
# ...
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
# ...
# '/home/sander/local/MATLAB/tapas/HGF'

# %%
dffit = df.groupby(['subjectId', 'group']).SRS_TOTAAL.mean().reset_index()
dffit['om'] = 0.0

fits = []
for s in ['1']: #df['subjectId'].unique():
    
    thisdf= df[df.subjectId == s]
    d = thisdf[['trial_mu','final']].to_numpy()
    
    ml.u = np.matrix(d[:,0]).T
    ml.y = np.matrix(d[:,1]).T
    fit = ml.tapas_fitModel(ml.y, ml.u,'tapas_hgf_config','tapas_gaussian_obs_config','tapas_quasinewton_optim_config')
    print(fit['p_prc']['om'][0][0])
    dffit.om = np.where(dffit.subjectId == s , fit['p_prc']['om'][0][0], dffit.om)

#pg.ttest(dffit[dffit.group=="ASD"].om, dffit[dffit.group=="TD"].om, paired=False, tail='two-sided').round(2)
# Out:
# Ignored trials: none
# Irregular trials: none
#
# Optimizing...
#
# ...
#
# Calculating the log-model evidence (LME)...
#
# Results:
#
# Parameter estimates for the perceptual model:
#     mu_0: [32 1]
#     sa_0: [249.0000 0.1000]
#      rho: [0 0]
#       ka: 1
#       om: [5.5175 -4]
#     pi_u: 0.0040
#
#
# Parameter estimates for the observation model:
#     ze: 0.0050
#
# Model quality:
#     LME (more is better): -155221128.1854
#     AIC (less is better): 310442260.2245
#     BIC (less is better): 310442288.1647
#
#     AIC and BIC are approximations to -2*LME = 310442256.3708.
#
# 5.517452896464707

# %% [markdown]
# # Explore instantaneous slopes (Vilares-style) over all phases

# %%
dfrt = df.groupby(['group','subjectId','trial_sigma']).mean().reset_index()

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=False, left=False)

# Show each observation with a scatterplot
sns.stripplot(x='trial_sigma', y="arc_slope", hue="group", data=dfrt, dodge=True, jitter=True,alpha=.4, zorder=1)


# Show the conditional means
sns.pointplot(x="trial_sigma", y="arc_slope", hue="group",
              data=dfrt, dodge=.532, join=False, palette="dark",
              markers="d", scale=.75)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[2:], labels[2:],
          handletextpad=0, columnspacing=1,
          loc="upper right", ncol=2, frameon=True);

# %%
dfslope = df.groupby(['SRSsplit','subjectId','trial_sigma']).arc_slope.mean().reset_index()

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=False, left=False)

# Show each observation with a scatterplot
sns.stripplot(x='trial_sigma', y="arc_slope", hue="SRSsplit", data=dfslope, dodge=True, jitter=True,alpha=.4, zorder=1)


# Show the conditional means
sns.pointplot(x="trial_sigma", y="arc_slope", hue="SRSsplit",
              data=dfslope, dodge=.532, join=False, palette="dark",
              markers="d", scale=.75)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[3:], labels[3:],
          handletextpad=0, columnspacing=1,
          loc="upper right", ncol=1, frameon=True);

# %%
ga = sm.families.Gaussian()
ex = sm.cov_struct.Exchangeable()

model1 = sm.GEE.from_formula("arc_slope ~ trial_sigma*group", groups="subjectId",data=df, family=ga, cov_struct=ex)
result1 = model1.fit()
print(result1.summary())
print(result1.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ...
# Dep. Variable:                   arc_slope   No. Observations:                19593
# Model:                                 GEE   No. clusters:                       49
# Method:                        Generalized   Min. cluster size:                 398
#                       Estimating Equations   Max. cluster size:                 400
# Family:                           Gaussian   Mean cluster size:               399.9
# Dependence structure:         Exchangeable   Num. iterations:                     3
# Date:                     Tue, 15 Oct 2019   Scale:                           0.098
# Covariance type:                    robust   Time:                         16:06:56
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interim conclusion
#
# No overall group differences in instantaneous slope (across blocks), but a significant effect of trialsigma: Larger slope (more weight on trial evidence) for lower sigma, as expected from a Bayesian point of view.

# %% [markdown]
# # Check for normalized rt differences

# %%
dfrt = df.groupby(['group','subjectId','trial_sigma']).mean().reset_index()

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=False, left=False)

# Show each observation with a scatterplot
sns.stripplot(x='trial_sigma', y="rt_norm", hue="group", data=dfrt, dodge=True, jitter=True,alpha=.4, zorder=1)

# Show the conditional means
sns.pointplot(x="trial_sigma", y="rt_norm", hue="group",
              data=dfrt, palette="dark",
              markers="d", dodge=.532, join=False, scale=.75)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[2:], labels[2:],
          handletextpad=0, columnspacing=1,
          loc="upper right", ncol=2, frameon=True);

# %%
sns.lmplot('SRS_TOTAAL','rt_norm',hue="group", data=dfrt);

# %% [markdown]
# ### Interim conclusion
#
# No overall group differences in rt (normalized by distance travelled; across blocks).

# %% [markdown]
# # Explore estimations

# %%
g = sns.FacetGrid(df, col="prior_mean", hue="prior_mean", height=5);

g.map(sns.distplot, "final");
ax = g.axes[0];
ax[0].axvline(22, ls='--', color='black');
ax[1].axvline(68, ls='--', color='black');

# %%
df.groupby(['prior_mean']).final.mean()
# Out:
# prior_mean
# 22    26.284637
# 68    67.968676
# Name: final, dtype: float64

# %%
#Distribution of estimates (like in L'aquitaine and Gardner), to check for bimodality
g = sns.FacetGrid(df, row="distance_prior_conv", col="prior", aspect=6, height=10);

# Draw the densities in a few steps
g.map(sns.distplot, "distance_prior_response_conv");
g.map(plt.axvline, x=0, lw=2, color='red', clip_on=False);

# %% [markdown]
# ### Interim conclusion
#
# Doesn't look bimodally distributed as in l'Aquitaine, so true Bayesian integration in the current study?

# %% [markdown]
# # Compare (rms) errors between conditions

# %%
# compute abs/rms errors
def fu(df):
    d = {}
    d['group']= df['group'].iloc[0]
    d['rms_error'] = np.sqrt(np.mean(df.distance_prior_response**2))
    d['abs_error'] = np.mean(np.abs(df.distance_prior_response))
    d['trial_error'] = np.mean(np.abs(df.distance_trial))
    return pd.Series(d)

# make df for grouped error data
error = df.groupby(['subjectId','trial_sigma']).apply(fu).reset_index()

for var in ["rms_error","abs_error", 'trial_error']:
    # Initialize the figure
    f, ax = plt.subplots()
    sns.despine(bottom=False, left=False)

    # Show each observation with a scatterplot
    sns.stripplot(x="trial_sigma", y=var, hue="group",
                  data=error, dodge=True, jitter=True,
                  alpha=.4, zorder=1)

    # Show the conditional means
    sns.pointplot(x="trial_sigma", y=var, hue="group",
                  data=error, dodge=.532, join=False, palette="dark",
                  markers="d", scale=.75)

    # Improve the legend 
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles[2:], labels[2:],
              handletextpad=0, columnspacing=1,
              loc="upper left", ncol=2, frameon=True)

# %%
ga = sm.families.Gaussian()
ex = sm.cov_struct.Exchangeable()

model1 = sm.GEE.from_formula("rms_error ~ trial_sigma*group", groups="subjectId",data=error, family=ga, cov_struct=ex)
result1 = model1.fit()
print(result1.summary())
print(result1.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ...
# Dep. Variable:                   rms_error   No. Observations:                   98
# Model:                                 GEE   No. clusters:                       49
# Method:                        Generalized   Min. cluster size:                   2
#                       Estimating Equations   Max. cluster size:                   2
# Family:                           Gaussian   Mean cluster size:                 2.0
# Dependence structure:         Exchangeable   Num. iterations:                     2
# Date:                     Tue, 15 Oct 2019   Scale:                          93.208
# Covariance type:                    robust   Time:                         16:30:26
# ...
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Interim conclusion
#
# No overall group differences in errors, but more errors in the high trial_sigma condition, as expected.

# %% [markdown]
# ## Errors per block

# %%
errorblock = df.groupby(['subjectId','block_index','trial_sigma']).apply(fu).reset_index()   

g = sns.FacetGrid(errorblock, col="trial_sigma", hue="group", height=6, aspect=.7)
g.map(sns.stripplot, "block_index", "rms_error", alpha=.3);
g.map(sns.pointplot, "block_index", "rms_error", jitter=.8);

g.add_legend();

# %%
md = smf.mixedlm("rms_error ~ trial_sigma*group*block_index", errorblock, groups=errorblock["subjectId"]).fit()
md.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                        Mixed Linear Model Regression Results
# ...
# Model:                      MixedLM          Dependent Variable:          rms_error
# No. Observations:           784              Method:                      REML
# No. Groups:                 49               Scale:                       100.6151
# Min. group size:            16               Likelihood:                  -2967.8516
# Max. group size:            16               Converged:                   Yes
# Mean group size:            16.0
# ------------------------------------------------------------------------------------
#                                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------
# Intercept                                 31.193    2.000 15.598 0.000 27.274 35.113
# ...

# %% [markdown]
# ### Interim conclusion
#
# There is clearer evidence of learning (reduction of errors over blocks) in the high trial_sigma condition (interaction effect block*sigma is signicant). The plot suggests the TD group learns a bit faster (in high sigma), but differences are small. In both sigma conditions there seems to be something different groupwise in the (transition to) the last two blocks. Increased errors in TD, while in ASD errors remain similar to the level before prior mean transition (last two blocks).

# %% [markdown]
# # Checking slopes of estimates (cf plots in vilares)

# %%
sns.lmplot(x="distance_prior_conv", y="distance_prior_response_conv", hue='trial_sigma', 
           units='subjectId', col='group', data=df[(df.tr_100.isin([3]))], x_estimator=np.mean);

# %%
sns.lmplot(x="distance_prior_conv", y="distance_prior_response_conv", hue='group', 
           units='subjectId', col='trial_sigma', data=df[(df.tr_100.isin([3]))], x_estimator=np.mean);

# %%
sns.lmplot(x="distance_prior_conv", y="distance_prior_response_conv", hue='group', 
           units='subjectId', col='trial_sigma', data=df[(df.tr_100.isin([4]))], x_estimator=np.mean);

# %%
dfsum = df.query("block_index==7 | block_index==6").groupby(['subjectId','group','trial_sigma','distance_prior_conv']).distance_prior_response_conv.mean().reset_index()
#sns.lmplot(x="distance_prior_conv", y="distance_prior_response_conv", hue='trial_sigma', units='id', col='group', data=dfsum, x_estimator=np.mean);

g = sns.FacetGrid(dfsum, col="trial_sigma", hue='group', height=5);
g.map(sns.regplot,"distance_prior_conv","distance_prior_response_conv", x_estimator=np.mean, fit_reg=False);
ax = g.axes[0];
ax[0].axhline(0, ls='--', color='grey')
ax[1].axhline(0, ls='--', color='grey')
ax[0].plot(dfsum.distance_prior_conv,dfsum.distance_prior_conv, ls='--', color='green')
ax[1].plot(dfsum.distance_prior_conv,dfsum.distance_prior_conv, ls='--', color='green')
g.add_legend();

# %% [markdown]
# ### Interim conclusion
#
# Lower slope means more influence of prior. We see there is more pull towards the prior in the high sigma condition, as expected. Other trends are hard to discern.

# %% [markdown]
# # Fit individual linear regressions to compare slopes

# %% [markdown]
# ### Function to do a linear regression for each person's data and give the slope, intercept and correlation

# %%
def est_slope(df): 
    d = {}
    d['group']= df['group'].iloc[0]
    d['session']= df['session'].iloc[0]
    d['slopeV'] = df['slope'].mean()
    d['arc_slope'] = df['arc_slope'].mean()
    lm = pg.linear_regression(df.distance_prior_conv, df.distance_prior_response_conv)
    d['intercept'] = lm.coef[0]
    d['slope'] = lm.coef[1]
    d['correlation'] = pg.corr(df.distance_prior_response_conv,df.distance_prior_conv).r[0]
    return pd.Series(d)

#Slope per person, group, trial_sigma and prior
df_est_cor_slope = df.groupby(['subjectId','trial_sigma', 'prior']).apply(est_slope).reset_index()

zscore = lambda x: (x - x.mean()) / x.std()
df_est_cor_slope['slope_z']= df_est_cor_slope.groupby(['subjectId'])['slope'].transform(zscore)
df_est_cor_slope['corr_z']= df_est_cor_slope.groupby(['subjectId'])['correlation'].transform(zscore)
df_est_cor_slope['intercept_z']= df_est_cor_slope.groupby(['subjectId'])['intercept'].transform(zscore)

# %% [markdown]
# ### Function to do a *rolling* linear regression for each person's data

# %%
df = df.assign(constant=1)

def ols_predict(indices, result, ycol, xcols):
    roll_df = df.loc[indices] # get relevant data frame subset
    result[indices[-1]] = sm.OLS(roll_df[ycol], roll_df[xcols]).fit().params
    return 0 # value is irrelevant here

# define kwargs to be fed to the ols_predict
kwargs = {"xcols": ['constant','distance_prior_conv'], 
          "ycol": 'distance_prior_response_conv', "result": {}}

# iterate id's sub data frames and call ols for rolling windows
df["identifier"] = df.index
for idx, sub_df in df.groupby(["subjectId","trial_sigma", "tr_100"]):
    sub_df["identifier"].rolling(10, min_periods=1).apply(ols_predict, kwargs=kwargs)

    
# write results back to original df
pars = pd.DataFrame(kwargs["result"])

# %%
pars = pars.transpose()
pars.rename(columns={'constant':'intercept', 'distance_prior_conv':'rollslope'}, inplace=True)

df['intercept']= pars.intercept
df['rollslope']= pars.rollslope

df['rollslope_z']= df.groupby(['subjectId'])['rollslope'].transform(zscore)

# %%
sns.regplot(x="rollslope", y="arc_slope", data=df.groupby(['subjectId']).mean());

# %%
df_rollslope = df.groupby(["subjectId",'group', "trial_sigma",'prior'],observed=True).rollslope_z.mean().reset_index()

g = sns.FacetGrid(df_rollslope, col="trial_sigma", hue="group", height=6, aspect=.7)
g.map(sns.stripplot, "prior", "rollslope_z", alpha=.3);
g.map(sns.pointplot, "prior", "rollslope_z", jitter=.8);
g.add_legend();

# %%
for var in ["slope","intercept","correlation"]:
    g = sns.FacetGrid(df_est_cor_slope, col="trial_sigma", hue="group", height=6, aspect=.7)
    g.map(sns.stripplot, "prior", var, alpha=.3);
    g.map(sns.pointplot, "prior", var, jitter=.8);
    g.add_legend();

# %%
ga = sm.families.Gaussian()
ex = sm.cov_struct.Exchangeable()

model1 = sm.GEE.from_formula("slope_z ~ group  * trial_sigma * prior", groups="subjectId",data=df_est_cor_slope, family=ga, cov_struct=ex)
result1 = model1.fit()
print(result1.summary())
print(result1.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ...
# Dep. Variable:                     slope_z   No. Observations:                  196
# Model:                                 GEE   No. clusters:                       49
# Method:                        Generalized   Min. cluster size:                   4
#                       Estimating Equations   Max. cluster size:                   4
# Family:                           Gaussian   Mean cluster size:                 4.0
# Dependence structure:         Exchangeable   Num. iterations:                     2
# Date:                     Tue, 15 Oct 2019   Scale:                           0.551
# Covariance type:                    robust   Time:                         18:08:23
# ...
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# ...

# %%
ga = sm.families.Gaussian()
ex = sm.cov_struct.Exchangeable()

model1 = sm.GEE.from_formula("rollslope_z ~ group  * trial_sigma * prior", groups="subjectId",data=df, family=ga, cov_struct=ex)
result1 = model1.fit()
print(result1.summary())
print(result1.cov_struct.summary())

# Is it necessary to do mixed model if standardized slope (based on id)?
results = smf.ols('rollslope_z ~ group  * trial_sigma * prior', data=df).fit()
print(results.summary())
# Out:
#                                GEE Regression Results
# ...
# Dep. Variable:                 rollslope_z   No. Observations:                19600
# Model:                                 GEE   No. clusters:                       49
# Method:                        Generalized   Min. cluster size:                 400
#                       Estimating Equations   Max. cluster size:                 400
# Family:                           Gaussian   Mean cluster size:               400.0
# Dependence structure:         Exchangeable   Num. iterations:                     2
# Date:                     Tue, 15 Oct 2019   Scale:                           0.977
# Covariance type:                    robust   Time:                         18:08:34
# ...
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# ...

# %%
ga = sm.families.Gaussian()
ex = sm.cov_struct.Exchangeable()

model1 = sm.GEE.from_formula("intercept_z ~ group  * trial_sigma * prior", groups="subjectId",data=df_est_cor_slope, family=ga, cov_struct=ex)
result1 = model1.fit()
print(result1.summary())
print(result1.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ...
# Dep. Variable:                     slope_z   No. Observations:                  196
# Model:                                 GEE   No. clusters:                       49
# Method:                        Generalized   Min. cluster size:                   4
#                       Estimating Equations   Max. cluster size:                   4
# Family:                           Gaussian   Mean cluster size:                 4.0
# Dependence structure:         Exchangeable   Num. iterations:                     2
# Date:                     Tue, 17 Sep 2019   Scale:                           0.551
# Covariance type:                    robust   Time:                         19:11:08
# ...
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Is it necessary to do mixed model if standardized slope (based on id)?
results = smf.ols('slope_z ~ group  * trial_sigma * prior', data=df_est_cor_slope).fit()
print(results.summary())

#the R lmer model also gives a significant interaction between prior and group (and similar effect of sigma & prior)        
#lmer_slope <- lmer(slope_z ~ group  * trial_sigma* prior + (trial_sigma|id)+ (prior|id), REML=F, data = df_est_cor_slope)
#summary(lmer_slope)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                slope_z   R-squared:                       0.296
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     11.27
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           6.85e-12
# Time:                        18:14:10   Log-Likelihood:                -215.59
# No. Observations:                 196   AIC:                             447.2
# Df Residuals:                     188   BIC:                             473.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# ...

# %%
from bambi import Model

# Assume we already have our data loaded
model = Model(df_est_cor_slope)
results = model.fit('slope_z ~ 1 + group * trial_sigma * prior', random=['trial_sigma|id', 'prior|id', '1|id'], samples=5000, chains=2)
results[1000:].plot()
results[1000:].summary()

# %%
results[1000:].summary().round(3)
# Out:
#                                                  mean     sd  hpd0.95_lower  \
# Intercept                                       0.594  0.152          0.287
# prior[T.prior 2]                               -0.596  0.215         -1.025
# group[T.TD]                                    -0.115  0.210         -0.511
# group[T.TD]:prior[T.prior 2]                    0.645  0.301          0.091
# 1|id_sd                                         0.047  0.035          0.000
# slope_z_sd                                      0.742  0.039          0.667
# trial_sigma[T.40]                              -0.638  0.216         -1.040
# group[T.TD]:trial_sigma[T.40]                  -0.165  0.299         -0.780
# trial_sigma[T.40]:prior[T.prior 2]              0.087  0.302         -0.530
# prior[T.prior 2]|id_sd                          0.148  0.104          0.000
# group[T.TD]:trial_sigma[T.40]:prior[T.prior 2] -0.493  0.422         -1.314
# ...

# %% [markdown]
# # Evolution of slopes over blocks

# %% [markdown]
# ### Fitted slope

# %%
#Slope per person, group, trial_sigma and tr_100
df_est_cor_slope = df.groupby(['subjectId','trial_sigma', 'block_index']).apply(est_slope).reset_index()

#Scale variables
df_est_cor_slope['slope_z']= df_est_cor_slope.groupby(['subjectId'])['slope'].transform(zscore)
df_est_cor_slope['corr_z']= df_est_cor_slope.groupby(['subjectId'])['correlation'].transform(zscore)
df_est_cor_slope['intercept_z']= df_est_cor_slope.groupby(['subjectId'])['intercept'].transform(zscore)
df_est_cor_slope['MuP']= df_est_cor_slope.intercept/(1-df_est_cor_slope.slope)

#Slope etc per 50/100 trials
for var in ['slope', 'intercept', 'MuP']:
    sns.factorplot(x='block_index', y=var, units='subjectId', hue='group', col='trial_sigma', data=df_est_cor_slope,
          kind='point',jitter=True, dodge=.1);

# %% [markdown]
# ### Instantaneous (arc)slope

# %%
#instantaneous slope per 50 trials
df_arc_slope = df.groupby(['block_index', 'group','subjectId','trial_sigma']).arc_slope.mean().reset_index()
                           
sns.factorplot(x='tr_100', y='arc_slope', units='subjectId', hue='group', col='trial_sigma', data=df,
          kind='point',jitter=True, dodge=0.2);
sns.factorplot(x='block_index', y='arc_slope', units='subjectId', hue='group', col='trial_sigma', data=df_arc_slope,
          kind='point',jitter=True, dodge=0.2);
sns.factorplot(x='block_index', y='slope', units='subjectId', hue='group', col='trial_sigma', data=df_est_cor_slope,
          kind='point',jitter=True, dodge=.1);

# %% [markdown]
# ### Rollslope

# %%
df_roll_slope = df.groupby(['block_index', 'group','subjectId', 'trial_sigma']).rollslope.mean().reset_index()
                           

sns.factorplot(x='block_index', y='rollslope', units='subjectId', col='trial_sigma', hue='group', data=df_roll_slope,
          kind='point',jitter=True, dodge=0.2);

# %% [markdown]
# ### Intercept

# %%
sns.factorplot(x='block_index', y='intercept', units='subjectId', col='trial_sigma', hue='group', data=df,
          kind='point',jitter=True, dodge=0.2);

# %%
ga = sm.families.Gaussian()
ex = sm.cov_struct.Exchangeable()

model1 = sm.GEE.from_formula("arc_slope ~ group  * trial_sigma * block_index", groups="subjectId",data=df, family=ga, cov_struct=ex)
result1 = model1.fit()
print(result1.summary())
print(result1.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ...
# Dep. Variable:                   arc_slope   No. Observations:                19593
# Model:                                 GEE   No. clusters:                       49
# Method:                        Generalized   Min. cluster size:                 398
#                       Estimating Equations   Max. cluster size:                 400
# Family:                           Gaussian   Mean cluster size:               399.9
# Dependence structure:         Exchangeable   Num. iterations:                     4
# Date:                     Tue, 15 Oct 2019   Scale:                           0.098
# Covariance type:                    robust   Time:                         18:21:41
# ...
#                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
ga = sm.families.Gaussian()
ex = sm.cov_struct.Exchangeable()

model1 = sm.GEE.from_formula("rollslope ~ group  * trial_sigma * block_index", groups="subjectId",data=df, family=ga, cov_struct=ex)
result1 = model1.fit()
print(result1.summary())
print(result1.cov_struct.summary())
# Out:
#                                GEE Regression Results
# ...
# Dep. Variable:                   rollslope   No. Observations:                19600
# Model:                                 GEE   No. clusters:                       49
# Method:                        Generalized   Min. cluster size:                 400
#                       Estimating Equations   Max. cluster size:                 400
# Family:                           Gaussian   Mean cluster size:               400.0
# Dependence structure:         Exchangeable   Num. iterations:                     4
# Date:                     Tue, 15 Oct 2019   Scale:                           0.698
# Covariance type:                    robust   Time:                         18:21:56
# ...
#                                                 coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Comparing instantaneous slope of last n trials before and n trials after shift in prior

# %%
n=20
lower = 308-n
upper= 307+n

#Instantaneous slope of last n trials before and n trials after shift in prior (if distance prior is 0, slope is 0 as well)
slopes_shift = (df.query('distance_prior != 0')
                  .query('(trial_index>@lower & trial_index<308) | (trial_index<@upper & trial_index>307)')
                  .groupby(['group','subjectId','block_index','trial_sigma'])
                  .arc_slope.mean().reset_index()
                  .pivot_table(index=['subjectId','group','trial_sigma'],columns='block_index',values='arc_slope').reset_index()
                  .rename(columns={5: "last_20", 6: "first_20"})
                  .assign(diff_slope=lambda x: x.first_20 - x.last_20))


# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=False, left=False)

# Show each observation with a scatterplot
sns.stripplot(x='trial_sigma', y="diff_slope", hue="group", data=slopes_shift, dodge=True, jitter=True,alpha=.4, zorder=1)

# Show the conditional means
sns.pointplot(x="trial_sigma", y="diff_slope", hue="group",
              data=slopes_shift, dodge=.532, join=False, palette="dark",
              markers="d", scale=.75)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[2:], labels[2:],
          handletextpad=0, columnspacing=1,
          loc="upper right", ncol=2, frameon=True);

md = smf.mixedlm("diff_slope ~ group*trial_sigma", slopes_shift, groups=slopes_shift["subjectId"]).fit()
print(md.summary())
# Out:
#                  Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM      Dependent Variable:      diff_slope
# No. Observations:       98           Method:                  REML
# No. Groups:             49           Scale:                   0.0149
# Min. group size:        2            Likelihood:              51.5412
# Max. group size:        2            Converged:               Yes
# Mean group size:        2.0
# ------------------------------------------------------------------------
#                               Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     -0.055    0.027 -2.038 0.042 -0.107 -0.002
# group[T.TD]                    0.058    0.038  1.551 0.121 -0.015  0.132
# trial_sigma[T.40]              0.000    0.035  0.010 0.992 -0.069  0.069
# group[T.TD]:trial_sigma[T.40]  0.041    0.049  0.836 0.403 -0.055  0.138
# ...

# %%
n=20
lower = 308-n
upper= 307+n


#roll slope of last 20 trials before and 20 trials after shift in prior (if distance prior is 0, slope is 0 as well)
slopes_shift = (df.query('distance_prior != 0')
                  .query('(trial_index>@lower & trial_index<308) | (trial_index<@upper & trial_index>307)')
                  .groupby(['group','subjectId', 'trial_sigma', 'block_index'])
                  .rollslope_z.mean().reset_index()
                  .pivot_table(index=['subjectId','group', 'trial_sigma'],columns='block_index',values='rollslope_z').reset_index()
                  .rename(columns={5: "last_20", 6: "first_20"})
                  .assign(diff_slope=lambda x: x.first_20 - x.last_20))


# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=False, left=False)

# Show each observation with a scatterplot
sns.stripplot(x='trial_sigma', y="diff_slope", hue="group", data=slopes_shift, dodge=True, jitter=True,alpha=.4, zorder=1)

# Show the conditional means
sns.pointplot(x="trial_sigma", y="diff_slope", hue="group",
              data=slopes_shift, dodge=.532, join=False, palette="dark",
              markers="d", scale=.75)

# Improve the legend 
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[2:], labels[2:],
          handletextpad=0, columnspacing=1,
          loc="upper right", ncol=2, frameon=True);

md = smf.mixedlm("diff_slope ~ group*trial_sigma", slopes_shift, groups=slopes_shift["subjectId"]).fit()
print(md.summary())
# Out:
#                  Mixed Linear Model Regression Results
# ...
# Model:                  MixedLM      Dependent Variable:      diff_slope
# No. Observations:       98           Method:                  REML
# No. Groups:             49           Scale:                   1.6600
# Min. group size:        2            Likelihood:              -165.8145
# Max. group size:        2            Converged:               Yes
# Mean group size:        2.0
# ------------------------------------------------------------------------
#                               Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------
# Intercept                     -0.189    0.269 -0.701 0.484 -0.717  0.339
# group[T.TD]                    0.268    0.377  0.711 0.477 -0.471  1.007
# trial_sigma[T.40]             -0.032    0.372 -0.087 0.931 -0.761  0.697
# group[T.TD]:trial_sigma[T.40]  0.356    0.521  0.685 0.494 -0.664  1.377
# ...

# %%
slopes_long = (df.query('distance_prior != 0')
                       .query('(trial_index>287 & trial_index<307) | (trial_index<327 & trial_index>306)')
                       .groupby(['group','subjectId','block_index','trial_sigma'])
                       .agg({'rollslope_z': ['mean','count']}).reset_index())

slopes_long.columns = [''.join(col).strip() for col in slopes_long.columns.values]
slopes_long["block_index"] = slopes_long["block_index"].astype('category')



f = plt.figure();
sns.factorplot(x='block_index', y='rollslope_zmean', units='subjectId', 
               hue='group', col='trial_sigma', data=slopes_long, kind='point',jitter=True, dodge=0.1);

# %%
md = smf.ols("rollslope_z ~ trial_sigma*group*block_index", df.query('distance_prior != 0').query('(trial_index>267 & trial_index<327) | (trial_index<347 & trial_index>286)')).fit()
print(md.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            rollslope_z   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     12.36
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           1.08e-15
# Time:                        19:10:50   Log-Likelihood:                -4521.7
# No. Observations:                3093   AIC:                             9059.
# Df Residuals:                    3085   BIC:                             9108.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# TODO:
#
# - estimate variability? (cf karvelis)
# - rts after switch?
# - stuctural priors?
# - Do we have a plot to show that ASD group learned the inferred mean slower/less after or during block 4? Errors seem to indicate the opposite?

# %%
sns.relplot(x="trial_mu", y="bias", col='trial_sigma',hue='group', data=df, kind="line");

# %%
sds = df.groupby(['group', 'subjectId', 'distance_prior', 'trial_sigma'], observed=True).final.std().reset_index()

sds

sns.relplot(x="distance_prior", y="final", col="trial_sigma",hue='group', data=sds, kind="line");
